# %%
# Create Matrix B by adding +1 to A[0,0]
B = A.copy()
B[0, 0] += 1

print("\nMatrix B:")
print(B)

# Shape
print("Shape:", B.shape)

# Determinant
det_B = np.linalg.det(B)
print("Determinant:", det_B)

# Rank
rank_B = np.linalg.matrix_rank(B)
print("Rank:", rank_B)

# Eigenvalues
eigen_B = np.linalg.eigvals(B)
print("Eigenvalues:", eigen_B)

# Inverse
if det_B != 0:
    inverse_B = np.linalg.inv(B)
    print("Inverse:")
    print(inverse_B)
# Out:
# Matrix B:
# [[ 9  4]
#  [12  5]]
# Shape: (2, 2)
# Determinant: -3.0000000000000004
# Rank: 2
# Eigenvalues: [14.21110255 -0.21110255]
# Inverse:
# [[-1.66666667  1.33333333]
#  [ 4.         -3.        ]]
